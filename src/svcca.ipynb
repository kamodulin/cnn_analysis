# %%
import numpy as np
import torch
import os

from matplotlib import pyplot as plt
from models import AlexNet
from svcca import cca_core

# %%
root = "~data/activations/"
activation_files = sorted(os.listdir(root), key=lambda x: x.split('-')[1])
A_f = torch.load(root+activation_files[-1])

scores = []

for num, activations in enumerate(activation_files):
    print(f"Comparing final activations with model_{num}")
    
    A_i = torch.load(root+activations)
    
    for layer in ['dense1', 'dense2', 'dense3']:
        print(f"------{layer}")
        
        cca = cca_core.get_cca_similarity(A_i[layer].T.cpu().detach().numpy(),
                                          A_f[layer].T.cpu().detach().numpy(),
                                          epsilon=1e-6)
        
        score = np.mean(cca["cca_coef1"])
        
        scores.append(score)
        
np.savetxt('scores.csv', scores, delimiter=',')
# Out:
# Comparing final activations with model_0
# ------dense1
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense2
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense3
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# Comparing final activations with model_1
# ------dense1
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense2
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense3
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# Comparing final activations with model_2
# ------dense1
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense2
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense3
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# Comparing final activations with model_3
# ------dense1
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense2
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense3
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# Comparing final activations with model_4
# ------dense1
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense2
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense3
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# Comparing final activations with model_5
# ------dense1
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense2
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense3
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# Comparing final activations with model_6
# ------dense1
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense2
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense3
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# Comparing final activations with model_7
# ------dense1
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense2
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense3
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# Comparing final activations with model_8
# ------dense1
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense2
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense3
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# Comparing final activations with model_9
# ------dense1
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense2
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense3
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# Comparing final activations with model_10
# ------dense1
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense2
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense3
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# Comparing final activations with model_11
# ------dense1
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense2
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense3
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# Comparing final activations with model_12
# ------dense1
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense2
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense3
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# Comparing final activations with model_13
# ------dense1
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense2
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense3
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# Comparing final activations with model_14
# ------dense1
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense2
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense3
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# Comparing final activations with model_15
# ------dense1
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense2
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense3
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# Comparing final activations with model_16
# ------dense1
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense2
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense3
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# Comparing final activations with model_17
# ------dense1
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense2
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense3
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# Comparing final activations with model_18
# ------dense1
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense2
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense3
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# Comparing final activations with model_19
# ------dense1
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense2
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense3
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# Comparing final activations with model_20
# ------dense1
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense2
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense3
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# Comparing final activations with model_21
# ------dense1
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense2
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense3
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# Comparing final activations with model_22
# ------dense1
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense2
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense3
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# Comparing final activations with model_23
# ------dense1
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense2
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense3
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# Comparing final activations with model_24
# ------dense1
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense2
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense3
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# Comparing final activations with model_25
# ------dense1
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense2
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense3
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# Comparing final activations with model_26
# ------dense1
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense2
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense3
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# Comparing final activations with model_27
# ------dense1
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense2
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense3
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# Comparing final activations with model_28
# ------dense1
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense2
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense3
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# Comparing final activations with model_29
# ------dense1
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense2
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense3
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# Comparing final activations with model_30
# ------dense1
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense2
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense3
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# Comparing final activations with model_31
# ------dense1
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense2
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense3
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# Comparing final activations with model_32
# ------dense1
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense2
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense3
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# Comparing final activations with model_33
# ------dense1
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense2
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense3
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# Comparing final activations with model_34
# ------dense1
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense2
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense3
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# Comparing final activations with model_35
# ------dense1
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense2
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense3
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# Comparing final activations with model_36
# ------dense1
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense2
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense3
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# Comparing final activations with model_37
# ------dense1
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense2
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense3
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# Comparing final activations with model_38
# ------dense1
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense2
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense3
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# Comparing final activations with model_39
# ------dense1
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense2
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense3
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# Comparing final activations with model_40
# ------dense1
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense2
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense3
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# Comparing final activations with model_41
# ------dense1
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense2
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense3
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# Comparing final activations with model_42
# ------dense1
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense2
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense3
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# Comparing final activations with model_43
# ------dense1
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense2
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense3
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# Comparing final activations with model_44
# ------dense1
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense2
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense3
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# Comparing final activations with model_45
# ------dense1
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense2
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense3
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# Comparing final activations with model_46
# ------dense1
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense2
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense3
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# Comparing final activations with model_47
# ------dense1
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense2
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense3
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# Comparing final activations with model_48
# ------dense1
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense2
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense3
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# Comparing final activations with model_49
# ------dense1
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense2
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense3
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# Comparing final activations with model_50
# ------dense1
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense2
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense3
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# Comparing final activations with model_51
# ------dense1
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense2
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense3
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# Comparing final activations with model_52
# ------dense1
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense2
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense3
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# Comparing final activations with model_53
# ------dense1
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense2
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense3
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# Comparing final activations with model_54
# ------dense1
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense2
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense3
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# Comparing final activations with model_55
# ------dense1
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense2
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense3
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# Comparing final activations with model_56
# ------dense1
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense2
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense3
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# Comparing final activations with model_57
# ------dense1
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense2
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense3
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# Comparing final activations with model_58
# ------dense1
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense2
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense3
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# Comparing final activations with model_59
# ------dense1
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense2
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense3
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# Comparing final activations with model_60
# ------dense1
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense2
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense3
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# Comparing final activations with model_61
# ------dense1
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense2
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense3
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# Comparing final activations with model_62
# ------dense1
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense2
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense3
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# Comparing final activations with model_63
# ------dense1
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense2
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense3
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# Comparing final activations with model_64
# ------dense1
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense2
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense3
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# Comparing final activations with model_65
# ------dense1
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense2
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense3
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# Comparing final activations with model_66
# ------dense1
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense2
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense3
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# Comparing final activations with model_67
# ------dense1
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense2
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense3
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# Comparing final activations with model_68
# ------dense1
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense2
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense3
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# Comparing final activations with model_69
# ------dense1
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense2
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense3
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# Comparing final activations with model_70
# ------dense1
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense2
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense3
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# Comparing final activations with model_71
# ------dense1
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense2
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense3
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# Comparing final activations with model_72
# ------dense1
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense2
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense3
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# Comparing final activations with model_73
# ------dense1
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense2
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense3
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# Comparing final activations with model_74
# ------dense1
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense2
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense3
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# Comparing final activations with model_75
# ------dense1
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense2
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense3
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# Comparing final activations with model_76
# ------dense1
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense2
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense3
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# Comparing final activations with model_77
# ------dense1
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense2
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense3
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# Comparing final activations with model_78
# ------dense1
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense2
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense3
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# Comparing final activations with model_79
# ------dense1
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense2
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense3
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# Comparing final activations with model_80
# ------dense1
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense2
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense3
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# Comparing final activations with model_81
# ------dense1
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense2
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense3
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# Comparing final activations with model_82
# ------dense1
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense2
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense3
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# Comparing final activations with model_83
# ------dense1
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense2
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense3
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# Comparing final activations with model_84
# ------dense1
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense2
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense3
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# Comparing final activations with model_85
# ------dense1
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense2
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense3
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# Comparing final activations with model_86
# ------dense1
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense2
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense3
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# Comparing final activations with model_87
# ------dense1
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense2
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense3
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# Comparing final activations with model_88
# ------dense1
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense2
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense3
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# Comparing final activations with model_89
# ------dense1
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense2
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
# ------dense3
# adding eps to diagonal and taking inverse
# taking square root
# dot products...
# trying to take final svd
# computed everything!
